# %%
key = 'sk-proj-z7cdW04c47VF3M1CLERiT3BlbkFJeeQfo2UvBqlzb5i8WkVF'

# %%
import openai

# Set your OpenAI API key
api_key = key
openai.api_key = api_key

# Example question
question = "What are memory models?"

# Call OpenAI's completion endpoint to answer the question
response = openai.Completion.create(
    engine="davinci",  # Choose the engine ("davinci" is recommended for general questions)
    prompt=question,
    max_tokens=50  # Adjust as needed
)

# Extract and print the answer
answer = response['choices'][0]['text'].strip()
print(f"Answer: {answer}")
